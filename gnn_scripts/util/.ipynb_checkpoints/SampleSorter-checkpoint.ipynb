# %%
import awkward as ak
import numpy as np
import uproot
import matplotlib.pyplot as plt 
from scipy.spatial import Delaunay
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
import torch.optim as optim
from torch_geometric.data import Data, Dataset
import os
from torch_geometric.loader import DataLoader
from torch.utils.data import ConcatDataset
import glob
from torch_geometric.nn import GCNConv as gcn
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from torch_geometric.nn import EdgeConv 
import csv
import sys
from torch_geometric.nn import global_mean_pool

# %%
#For the larger test set I used file numbers 6100-8000. This is a lot to load at once, so will only grab the first 1000 (

# %%
#Training Stuff
SEED = 2026
np.random.seed(SEED)    # Setting the seed for reproducibility
torch.manual_seed(SEED)
#signal_directory = '/standard/ldmxuva/gnn_files/note_stuff/training_graphs/signal/processed'
#dimuon_directory = '/standard/ldmxuva/gnn_files/note_stuff/training_graphs/dimuon/processed'
enriched_directory = '/standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/'

#Path to our batches
#signal_file_paths = glob.glob(os.path.join(signal_directory, "training*"))
#dimuon_file_paths = glob.glob(os.path.join(dimuon_directory, "training*"))
enriched_file_paths = glob.glob(os.path.join(enriched_directory, "validation*"))

#signal_training_list = []
#dimuon_training_list = []
enriched_training_list = []

# %%
for i, path in enumerate(enriched_file_paths):
    enriched_training_list.append(torch.load(path, weights_only = False))
    if (i % 10 == 0) :
        print(path)

    if (i > 1000):
        break
# Out:
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4147_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4464_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4817_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4318_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4376_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4852_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4174_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4847_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4907_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4150_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4582_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4315_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4785_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4602_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4461_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4678_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4703_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4431_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4106_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4910_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4816_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4290_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4104_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4774_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4899_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4916_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4978_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4465_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4006_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4263_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4549_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4574_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4076_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4220_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4488_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4948_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4572_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4017_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4966_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4934_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4795_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4165_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4578_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4735_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4453_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4780_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4317_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4470_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4207_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4171_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4668_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4080_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4656_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4450_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4814_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4782_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4927_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4752_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4923_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4300_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4170_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4078_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4495_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4690_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4370_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4762_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4502_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4304_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4891_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4030_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4808_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4960_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4218_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4024_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4687_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4998_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4967_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4992_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4154_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4623_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4022_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4134_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4248_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4585_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4536_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4569_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4029_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4226_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4519_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4575_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4773_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4707_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4467_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4714_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4394_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4112_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4740_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4616_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/training_graphs/enriched/processed/training_enriched_background_4119_graphs.pt

# %%
torch.save(enriched_training_list, "/standard/ldmxuva/gnn_files/note_stuff/big_enriched_merged_1.pt")
