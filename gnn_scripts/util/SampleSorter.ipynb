# %%
import awkward as ak
import numpy as np
import uproot
import matplotlib.pyplot as plt 
from scipy.spatial import Delaunay
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
import torch.optim as optim
from torch_geometric.data import Data, Dataset
import os
from torch_geometric.loader import DataLoader
from torch.utils.data import ConcatDataset
import glob
from torch_geometric.nn import GCNConv as gcn
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from torch_geometric.nn import EdgeConv 
import csv
import sys
from torch_geometric.nn import global_mean_pool

# %%
#For the larger test set I used file numbers 6100-8000. This is a lot to load at once, so will only grab the first 1000 (

# %%
#Training Stuff
SEED = 2026
np.random.seed(SEED)    # Setting the seed for reproducibility
torch.manual_seed(SEED)
#signal_directory = '/standard/ldmxuva/gnn_files/note_stuff/training_graphs/signal/processed'
#dimuon_directory = '/standard/ldmxuva/gnn_files/note_stuff/training_graphs/dimuon/processed'
enriched_directory = '/standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/'

#Path to our batches
#signal_file_paths = glob.glob(os.path.join(signal_directory, "training*"))
#dimuon_file_paths = glob.glob(os.path.join(dimuon_directory, "training*"))
enriched_file_paths = glob.glob(os.path.join(enriched_directory, "validation*"))

#signal_training_list = []
#dimuon_training_list = []
enriched_training_list = []

# %%
for i, path in enumerate(enriched_file_paths):
    enriched_training_list.append(torch.load(path, weights_only = False))
    if (i % 10 == 0) :
        print(path)

    if (i > 1000):
        break
# Out:
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6615_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7488_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6883_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7455_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6707_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6797_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6754_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7601_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7391_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7194_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6598_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7576_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7107_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7198_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6405_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7135_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7314_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6187_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6203_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6894_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6304_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6691_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7113_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6829_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6825_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7414_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6817_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6497_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6477_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7388_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6753_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7219_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7497_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7309_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6609_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6902_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7207_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7623_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6652_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7481_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6936_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6714_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6482_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6610_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6258_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6704_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6387_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6141_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7136_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7228_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6101_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7118_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6956_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6342_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6519_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6516_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7258_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7460_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6357_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6710_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6591_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7410_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7230_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6970_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7457_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6268_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6765_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7636_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7015_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6990_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7102_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6840_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6929_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6553_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6413_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7409_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7542_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6525_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7400_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7133_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7384_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7626_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6469_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6294_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7421_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6575_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7595_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7613_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7420_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6356_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6709_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6907_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7032_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6280_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7112_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6991_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7319_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6860_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7011_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_6559_graphs.pt
# /standard/ldmxuva/gnn_files/note_stuff/larger_test_graphs/processed/validation_enriched_background_7048_graphs.pt

# %%
torch.save(enriched_training_list, "/standard/ldmxuva/gnn_files/note_stuff/big_enriched_merged_1.pt")
